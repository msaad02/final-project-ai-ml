# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import utils

# %%
df = pd.read_csv("../../data/kaggleDataset/chessData.csv", nrows = 1_000_000)

# %%
eval = df.Evaluation.apply(utils.preprocess_scores)

# %%
eval = df.Evaluation

# %%
import matplotlib.pyplot as plt
# data = df.Evaluation.apply(preprocess_scores)  # arguments are passed to np.histogram

plt.hist(eval, bins=100)
plt.title("Histogram with 'auto' bins")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(eval, bins=100, range=(-2500, 2500), log=False)
plt.title("Histogram with 'auto' bins")
plt.show()
